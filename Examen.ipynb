# %% [markdown]
# # importamos la libreria de pandas

# %%
import pandas as pd
df = pd.read_csv("data_by_artist.csv")

# %% [markdown]
# # 10 artistas ordenados alfabeticamente.

# %%
df = df.head(10).sort_values(by='artists', ascending=True)

# %%
df
# Out:
#                                              artists  acousticness  \
# 0                   "Cats" 1981 Original London Cast      0.598500
# 1                          "Cats" 1983 Broadway Cast      0.862538
# 2        "Fiddler On The Roof” Motion Picture Chorus      0.856571
# 3     "Fiddler On The Roof” Motion Picture Orchestra      0.884926
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...      0.510714
# 5  "Joseph And The Amazing Technicolor Dreamcoat"...      0.591167
# 6                             "Mama" Helen Teagarden      0.725000
# 7                            "Test for Victor Young"      0.927000
# 8                                "Weird Al" Yankovic      0.186821
# 9                                             $0dg0d      0.110000
#
#    danceability    duration_ms    energy  instrumentalness  liveness  \
# 0      0.470100  267072.000000  0.376203          0.010261  0.283050
# 1      0.441731  287280.000000  0.406808          0.081158  0.315215
# ...

# %% [markdown]
# # posibles datos que puedan relacionar.

# %%
relation1 = df[['duration_ms','tempo']]

# %%
relation1
# Out:
#      duration_ms       tempo
# 0  267072.000000  114.128800
# 1  287280.000000  103.044154
# 2  328920.000000   77.375857
# 3  262890.962963   88.667630
# 4  270436.142857  122.835857
# 5  218504.500000  122.517833
# 6  135533.000000  134.819000
# 7  175693.000000  132.788000
# 8  218352.962264  132.876604
# 9  160171.000000  141.948000

# %%
relation2 = df[['danceability','instrumentalness']]

# %%
relation2
# Out:
#    danceability  instrumentalness
# 0      0.470100          0.010261
# 1      0.441731          0.081158
# 2      0.348286          0.024593
# 3      0.425074          0.073587
# 4      0.467143          0.009400
# 5      0.484333          0.007042
# 6      0.637000          0.186000
# 7      0.734000          0.076200
# 8      0.650792          0.000045
# 9      0.732000          0.000009

# %%
relation3 = df[['acousticness','liveness']]

# %%
relation3
# Out:
#    acousticness  liveness
# 0      0.598500  0.283050
# 1      0.862538  0.315215
# 2      0.856571  0.325786
# 3      0.884926  0.275481
# 4      0.510714  0.195000
# 5      0.591167  0.176067
# 6      0.725000  0.426000
# 7      0.927000  0.737000
# 8      0.186821  0.160926
# 9      0.110000  0.154000

# %% [markdown]
# # medio,promedio,varianza,valor maximo,valorminimo.

# %%
df.describe()
# Out:
#        acousticness  danceability   duration_ms        energy  \
# count  32539.000000  32539.000000  3.253900e+04  32539.000000
# mean       0.455682      0.552737  2.485982e+05      0.525908
# std        0.383678      0.176445  1.581808e+05      0.267402
# min        0.000000      0.000000  8.042000e+03      0.000000
# 25%        0.055155      0.436487  1.804616e+05      0.299000
# 50%        0.391833      0.563000  2.215070e+05      0.537375
# 75%        0.876000      0.684500  2.815870e+05      0.747039
# max        0.996000      0.987000  4.696690e+06      1.000000
#
#        instrumentalness      liveness      loudness   speechiness  \
# count      32539.000000  32539.000000  32539.000000  32539.000000
# mean           0.233281      0.209035    -11.008171      0.092047
# std            0.334487      0.151781      5.568630      0.111257
# min            0.000000      0.000000    -60.000000      0.000000
# 25%            0.000012      0.109000    -13.792500      0.039700
# ...

# %% [markdown]
# # ¿cuáles valores pueden tener una relacion lineal positiva, demuestra y diga el porque lo consideran asi?

# %%
import numpy as np 
import seaborn as sns 
from matplotlib import pyplot as plt 
# %matplotlib inline

# %%
sns.pairplot(relation3, kind='reg')
plt.show()

# %% [markdown]
# por que la acousticness tiene que ver con la liveness, ya que se pueden relacionar y podemos obtener relacion lineal

# %%
sns.pairplot(relation1, kind='reg')
plt.show()

# %% [markdown]
# podemos obtener una realcion lineal con la duracion ms y tempo, comom podemos obserbar en la prafica de ariba.

# %%
sns.pairplot(relation1, kind='reg')
plt.show()
